# %%
import dask.array as da
import numpy as np
from sklearn.manifold import TSNE

# %%
X = np.load('/Users/lsxliron/Desktop/Fortran_INP-FLUX/Jan2005.npy')
d = da.from_array(X, chunks=(1000,41))

# %%
model = TSNE(n_components=2, random_state=0)

# %%
z = model.fit_transform(d)

# %%
import dask.array as da
import numpy as np
from sklearn.manifold import TSNE
from dask.dot import dot_graph

X = np.load('/Users/lsxliron/Desktop/Fortran_INP-FLUX/Jan2005.npy')[0:1000]
d = da.from_array(X, chunks=(1000,41))
model = TSNE(n_components=2, random_state=0)
z = da.from_array(model.fit_transform(d), chunks=(500,2))

# %%
dot_graph(z.dask)
